# %% [markdown]
# ## K-MEANS Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)  # rc => runtime configuration

# Creating a sample dataset with 4 clusters
X, y = make_blobs(n_samples = 800, n_features = 3, 
                  centers = 4)
print ("X = ",X, X.shape)
# print ("X[:,0] = ",X[:,0])
print ("y = ", y[:50], len(y))
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
# Out:
# X =  [[-1.81035313e-01 -6.96556960e+00  7.05437270e+00]
#  [-7.14613725e-02 -1.00996001e-01  1.01557293e+01]
#  [-1.23845820e+00  1.75970843e+00  1.03700855e+01]
#  ...
#  [-1.19284944e+01  6.52629780e-01  6.79469970e-01]
#  [-9.55989865e+00 -9.05905468e-02  1.54771453e-03]
#  [-1.02004207e+00 -5.55130136e+00  5.00054121e+00]] (800, 3)
# y =  [1 3 3 2 1 0 3 1 0 2 1 0 2 2 1 1 3 3 2 2 3 3 1 1 3 2 1 3 1 3 0 2 1 2 1 1 2
#  1 3 1 1 3 1 3 3 1 1 0 3 0] 800

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=4)
# Fitting with inputs
kmeans = kmeans.fit(X)
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_
print ("C =",C)
plt.rcParams['figure.figsize'] = (16, 9)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#000000', s=1000)
# Out:
# C = [[ 5.45539528 -1.37818488  4.90539363]
#  [-0.74421319 -8.27780075 -8.84043681]
#  [ 4.36949573 -7.83890216  6.8247381 ]
#  [ 6.08284981 -4.5608143  -3.9252843 ]]
